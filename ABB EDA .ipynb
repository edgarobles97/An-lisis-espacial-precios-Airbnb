# %% [markdown]
# # Código de la tesina

# %% [markdown]
# ### Fuente principal: Inside Airbnb (Murray Cox)
# #### Edgar Robles Díaz

# %%
### Primero importamos paquetería esencial para la manipulación y visualización de los datos ###

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# visualización geográfica #

# %%
import geopandas as gpd

# %%
# Ajustes de viusailzación de tablas #

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Importa la base de datos con los listados de Airbnb #

# %%
abnb = pd.read_csv("listados_limpio.csv", low_memory = False, encoding='latin1')

# %%
abnb.info()

# %%
### Muestra de las primeras cinco observaciones ###

# %%
abnb.head()

# %%
### Eliminar variables redundantes ###

# %%
##### Primero hay que limpiar los precios, es decir, quitarle el signo y puntuación y convertirlo a tipo flotante #####

# %%
### Calcular el número de NAs por variable

# %% [markdown]
# ### Tabla con distribución de datos

# %%
### Hacer tabla con distribución de precios por cuartiles y por delegación ###

# %%
abnb.neighbourhood_cleansed.unique()

# %%
### Separar por Delegación y filtrar los precios ###

# %%
sub_1 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Cuauhtémoc']
sub_2 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Cuajimalpa de Morelos']
sub_3 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Coyoacán']
sub_4 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Miguel Hidalgo']
sub_5 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Benito Juárez']
sub_6 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Iztacalco']
sub_7 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Tlalpan']
sub_8 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Azcapotzalco']
sub_9 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Iztapalapa']
sub_10 = abnb.loc[abnb['neighbourhood_cleansed'] == 'La Magdalena Contreras']
sub_11 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Venustiano Carranza']
sub_12 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Álvaro Obregón']
sub_13 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Gustavo A. Madero']
sub_14 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Xochimilco']
sub_15 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Tláhuac']
sub_16 = abnb.loc[abnb['neighbourhood_cleansed'] == 'Milpa Alta']


price_sub1=sub_1[['price']]
price_sub2=sub_2[['price']]
price_sub3=sub_3[['price']]
price_sub4=sub_4[['price']]
price_sub5=sub_5[['price']]
price_sub6=sub_6[['price']]
price_sub7=sub_7[['price']]
price_sub8=sub_8[['price']]
price_sub9=sub_9[['price']]
price_sub10=sub_10[['price']]
price_sub11=sub_11[['price']]
price_sub12=sub_12[['price']]
price_sub13=sub_13[['price']]
price_sub14=sub_14[['price']]
price_sub15=sub_15[['price']]
price_sub16=sub_16[['price']]

# %%
### Guardar los resultados en una lista ###

# %%
price_list_by_n=[price_sub1, price_sub2, price_sub3, price_sub4, price_sub5, price_sub6, 
                price_sub7, price_sub8, price_sub9, price_sub10, price_sub11, price_sub12,
                price_sub13, price_sub14, price_sub15, price_sub16]

# %%
p_l_b_n_2 = []

# %%
### Armar estadística descriptiva para cada subset de delegación ###

# %%
nei_list = ['Cuauhtémoc', 'Cuajimalpa de Morelos', 'Coyoacán',
       'Miguel Hidalgo', 'Benito Juárez', 'Iztacalco', 'Tlalpan',
       'Azcapotzalco', 'Iztapalapa', 'La Magdalena Contreras',
       'Venustiano Carranza', 'Álvaro Obregón', 'Gustavo A. Madero',
       'Xochimilco', 'Tláhuac', 'Milpa Alta']

for x in price_list_by_n:
    i = x.describe(percentiles=[0.25, 0.50, 0.75])
    i = i.iloc[3:]
    i.reset_index(inplace=True)
    i.rename(columns={'index':'Stats'}, inplace = True)
    p_l_b_n_2.append(i)

# %%
### Renombrar los nombres de las columnas con el nombre de la delegación respectiva

# %%
p_l_b_n_2[0].rename(columns = {'price':nei_list[0]}, inplace = True)
p_l_b_n_2[1].rename(columns = {'price':nei_list[1]}, inplace = True)
p_l_b_n_2[2].rename(columns = {'price':nei_list[2]}, inplace = True)
p_l_b_n_2[3].rename(columns = {'price':nei_list[3]}, inplace = True)
p_l_b_n_2[4].rename(columns = {'price':nei_list[4]}, inplace = True)
p_l_b_n_2[5].rename(columns = {'price':nei_list[5]}, inplace = True)
p_l_b_n_2[6].rename(columns = {'price':nei_list[6]}, inplace = True)
p_l_b_n_2[7].rename(columns = {'price':nei_list[7]}, inplace = True)
p_l_b_n_2[8].rename(columns = {'price':nei_list[8]}, inplace = True)
p_l_b_n_2[9].rename(columns = {'price':nei_list[9]}, inplace = True)
p_l_b_n_2[10].rename(columns = {'price':nei_list[10]}, inplace = True)
p_l_b_n_2[11].rename(columns = {'price':nei_list[11]}, inplace = True)
p_l_b_n_2[12].rename(columns = {'price':nei_list[12]}, inplace = True)
p_l_b_n_2[13].rename(columns = {'price':nei_list[13]}, inplace = True)
p_l_b_n_2[14].rename(columns = {'price':nei_list[14]}, inplace = True)
p_l_b_n_2[15].rename(columns = {'price':nei_list[15]}, inplace = True)

# %%
### Convertir a dataframe y unir todas las delegaciones en una sola tabla

# %%
stat_df = p_l_b_n_2
stat_df = [df.set_index('Stats') for df in stat_df]
stat_df = stat_df[0].join(stat_df[1:])
stat_df

# %% [markdown]
# ## Visualización de los datos

# %% [markdown]
# #### Sobreponer la ubicación de los Airbnbs en un mapa de la CDMX

# %%
import matplotlib.image as mpimg 
img = mpimg.imread('Desktop\mapa.png')

# %%
### Dataframe sin outliers (para una mejor visualización de los datos)

# %%
abnb_stats = abnb[abnb.price < 5000]

# %%
### Boxplot con los precios de las delegaciones ###

# %%
plt.figure(figsize=(20,15))
ax = sns.boxplot(x = 'neighbourhood_cleansed', y = 'price', data = abnb_stats)
plt.title('Distribución de precios de Airbnbs por Delegación')
plt.xticks(rotation = -45)
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.violinplot(y = 'neighbourhood_cleansed', x = 'price', data = abnb_stats)
plt.title('Distribución y densidad de precios de Airbnbs por Delegación')
plt.ylabel('Delegación')
plt.xlabel('Precio')
plt.show()
# Out:
# C:\Users\edari\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
abnb['latitude'].min()
# Out:
# 19.16817

# %%
abnb['latitude'].max()
# Out:
# 19.56534

# %%
import descartes

# %%
fp ='Desktop/alcaldias.shp'

# %%
map_df = gpd.read_file(fp)

# %%
map_df['nomgeo'].replace({
    
    
     'CuauhtÃ©moc':'Cuauhtémoc',
'Ãlvaro ObregÃ³n':'Álvaro Obregón',
        'TlÃ¡huac':'Tláhuac',
  'Benito JuÃ¡rez':'Benito Juárez',
       'CoyoacÃ¡n':'Coyoacán'
},
             inplace = True)

# %%
map_df.rename(columns={'nomgeo':'delegación'}, inplace = True)

# %%
abnb_stats.rename(columns={'neighbourhood_cleansed':'delegación'}, inplace =True)
# Out:
# C:\Users\edari\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
### Combinar los datos geográficos con los de Airbnb con la función merge ###

# %% [markdown]
# ###### Recuerda: Merge = Airbnb + datos geo x alcaldía

# %%
merge = map_df.merge(abnb_stats, on='delegación', how = 'inner')

# %%
merge.head()
# Out:
#    delegación cve_mun cve_ent cvegeo                                           geometry      id                          listing_url       scrape_id last_scraped                                               name                                            summary                                              space                                        description experiences_offered                              neighborhood_overview                                              notes                                            transit                                             access                                        interaction                                        house_rules  thumbnail_url  medium_url                                        picture_url  xl_picture_url  host_id                                  host_url                           host_name  host_since                          host_location                                         host_about  host_response_time  \
# ...

# %%
var = 'price'

# %%
### Crear el mapa ###

# %%
fig, ax = plt.subplots(1, figsize=(20, 10))

vmin, vamx = 0, 5000

merge.plot(column='price', cmap='Blues', ax= ax, scheme = 'quantiles',linewidth = 0.8, legend=True, edgecolor = '0.8')

ax.set_title('Precios de Airbnb por alcaldía en la CDMX', fontdict={'fontsize': '25', 'fontweight' : '3'})

ax.annotate('Fuente: Inside Airbnb, Murray Cox (2020)',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left',
            verticalalignment='top', fontsize=12, color='#555555')

plt.show()

# %%
merge.groupby('delegación')['price'].mean()
# Out:
# delegación
# Azcapotzalco               633.256098
# Benito Juárez              704.514303
# Coyoacán                   701.054857
# Cuajimalpa de Morelos     1176.646226
# Cuauhtémoc                1086.314947
# Gustavo A. Madero          569.002967
# Iztacalco                  518.626415
# Iztapalapa                 551.428030
# La Magdalena Contreras     798.802817
# Miguel Hidalgo            1251.226798
# Milpa Alta                 634.187500
# Tlalpan                    613.009401
# Tláhuac                    528.351351
# Venustiano Carranza        618.399449
# Xochimilco                 609.366906
# Álvaro Obregón             866.848128
# Name: price, dtype: float64

# %%
fp_2 = 'Desktop/CP_09CdMx_v2.shp'

# %%
map_df_2 = gpd.read_file(fp_2)

# %%
map_df_2.rename(columns={'d_cp':'zipcode'}, inplace = True)

# %%
abnb_stats_2 = abnb_stats.dropna(subset=['zipcode'])

# %%
abnb_stats_2 = abnb_stats_2[abnb_stats_2['zipcode'].str.len() == 5]

# %% [markdown]
# ###### Recuerda: Merge_2 = Airbnb + Datos x código postal

# %%
merge_2 = map_df_2.merge(abnb_stats_2, on='zipcode', how = 'inner')

# %%
merge_2.head()
# Out:
#   zipcode                                           geometry       id                           listing_url       scrape_id last_scraped                                               name                                            summary                                              space                                        description experiences_offered                              neighborhood_overview                                              notes                                            transit                                             access                                        interaction                                        house_rules  thumbnail_url  medium_url                                        picture_url  xl_picture_url  host_id                                   host_url        host_name  host_since                     host_location                                         host_about host_response_time host_response_rate  host_acceptance_rate  \
# ...

# %%
fig, ax = plt.subplots(1, figsize=(20, 10))

vmin, vamx = 0, 5000

merge_2.plot(column='price', cmap='brg', ax= ax, scheme='quantiles', linewidth = 0.8, legend=True,
           edgecolor = '0.8')

ax.set_title('Precios de Airbnb por código postal en la CDMX', fontdict={'fontsize': '25', 'fontweight' : '3'})

ax.annotate('Fuente: Inside Airbnb, Murray Cox (2020)',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left',
            verticalalignment='top', fontsize=12, color='#555555')

plt.show()
fig.savefig('cdmx_precios_cp.png', dpi=300)

# %% [markdown]
# ## Visualizaciones de la CDMX por número de listados

# %%
tabla = merge_2.delegación.value_counts().sort_values(ascending = False).to_frame()

# %%
tabla.reset_index(inplace=True)

# %%
tabla.rename(columns={'delegación':'Número de Listados', 'index':'delegación'}, inplace=True)

# %%
tabla_merge = map_df.merge(tabla, on='delegación', how = 'inner')

# %%
var='Número de Listados'
fig, ax = plt.subplots(1, figsize=(20, 10))

vmin, vamx = 0, 5000

tabla_merge.plot(column=var, cmap='Blues', ax= ax, scheme='quantiles', linewidth = 0.8, legend=True,
           edgecolor = '0.8')

ax.set_title('Número de Listados de Airbnb por alcaldía en la CDMX', fontdict={'fontsize': '25', 'fontweight' : '3'})

ax.annotate('Fuente: Inside Airbnb, Murray Cox (2020)',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left',
            verticalalignment='top', fontsize=12, color='#555555')

plt.show()

# %%
merge_2['zipcode'] = merge_2["zipcode"].astype(str).astype('int64')

# %%
tabla_2 = merge_2.zipcode.value_counts().sort_values(ascending = False).to_frame()

# %%
tabla_2.reset_index(inplace=True)

# %%
tabla_2.rename(columns={'zipcode':'Número de Listados', 'index':'zipcode'}, inplace=True)

# %%
tabla_merge_2 = map_df_2.merge(tabla_2, on='zipcode', how = 'inner')

# %%
colonia = pd.read_excel('Desktop\Ciudad de México.xls', sheet_name='Distrito_Federal')

# %%
colonia = colonia[['d_codigo','d_asenta', 'D_mnpio']]

# %%
colonia.rename(columns={'d_codigo':'zipcode', 'd_asenta':'neighbourhood', 'D_mnpio':'delegación'}, inplace =True)

# %%
colonia.reset_index(inplace=True)

# %%
tabla_merge_3 = tabla_merge_2.merge(colonia, on='zipcode', how = 'inner')

# %%
tabla_merge_clean = tabla_merge_3[['zipcode', 'Número de Listados', 'neighbourhood', 'delegación']].sort_values(by = ['Número de Listados', 'neighbourhood'], ascending = False)

# %%
tabla_merge_clean.reset_index().drop(columns='index').set_index('zipcode')
# Out:
#          Número de Listados                             neighbourhood              delegación
# zipcode
# 6700                   1632                                Roma Norte              Cuauhtémoc
# 6100                   1034                                 Hipódromo              Cuauhtémoc
# 6000                    748                           Centro (Área 1)              Cuauhtémoc
# 6140                    686                                   Condesa              Cuauhtémoc
# 6600                    668                                    Juárez              Cuauhtémoc
# 6500                    656                                Cuauhtémoc              Cuauhtémoc
# 3100                    551                     Insurgentes San Borja           Benito Juárez
# 3100                    551                          Del Valle Centro           Benito Juárez
# 6760                    509                                  Roma Sur              Cuauhtémoc
# ...

# %%
### Plot de los datos por Colonia ###

# %%
tabla

# %%
var='Número de Listados'
fig, ax = plt.subplots(1, figsize=(20, 10))

vmin, vamx = 0, 5000

tabla_merge_3.plot(column=var, cmap='brg', ax= ax, scheme='equalinterval', linewidth = 0.8, legend=True,
           edgecolor = '0.8')

ax.set_title('Número de Listados de Airbnb por Colonia en la CDMX', fontdict={'fontsize': '25', 'fontweight' : '3'})

ax.annotate('Fuente: Inside Airbnb, Murray Cox (2020)',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left',
            verticalalignment='top', fontsize=12, color='#555555')

plt.show()

# %% [markdown]
# ## Descripción de los datos

# %%
delegaciones = abnb.groupby(['neighbourhood_cleansed'])['last_scraped'].count()

# %%
### Estimar número de listados por delegación ###

# %%
delegaciones.to_frame().sort_values(by = 'last_scraped', ascending = False)
# Out:
#                         last_scraped
# neighbourhood_cleansed
# Cuauhtémoc                      8140
# Benito Juárez                   3321
# Miguel Hidalgo                  3273
# Coyoacán                        1770
# Álvaro Obregón                   952
# Tlalpan                          863
# Cuajimalpa de Morelos            431
# Venustiano Carranza              364
# Gustavo A. Madero                337
# Iztacalco                        269
# Iztapalapa                       267
# Azcapotzalco                     247
# La Magdalena Contreras           142
# Xochimilco                       142
# Tláhuac                           37
# Milpa Alta                        16

# %% [markdown]
# ##### Tabla con precios promedio por delegación

# %%
### Calcular el precio promedio por delegación ###

# %%
precio_x_del = abnb.groupby(['neighbourhood_cleansed'])['price'].mean()

# %%
num_x_del = tabla_merge[['delegación', 'Número de Listados']].sort_values(by = 'Número de Listados',ascending = False)

# %%
precio_x_del =precio_x_del.to_frame().reset_index().rename(columns={'neighbourhood_cleansed':'delegación'})

# %%
precio_num_x_del = precio_x_del.merge(num_x_del, on='delegación', how = 'inner')

# %%
precio_num_x_del.sort_values(by='Número de Listados', ascending=False).set_index('delegación')
# Out:
#                               price  Número de Listados
# delegación
# Cuauhtémoc              1268.737961                7708
# Benito Juárez            819.257453                3066
# Miguel Hidalgo          1575.362359                2927
# Coyoacán                 880.703390                1604
# Álvaro Obregón           986.460084                 844
# Tlalpan                  745.699884                 739
# Cuajimalpa de Morelos   1311.092807                 367
# Venustiano Carranza      657.884615                 338
# Gustavo A. Madero        569.002967                 298
# Iztacalco                637.278810                 243
# Iztapalapa              1988.168539                 225
# Azcapotzalco             709.109312                 214
# Xochimilco              2204.922535                 120
# La Magdalena Contreras   798.802817                 118
# Tláhuac                  528.351351                  29
# Milpa Alta               634.187500                  11

# %%
### Número de listafos por tipo de cuarto ###

# %%
tipo_cuarto = abnb.groupby('room_type')['id'].count()

# %%
tipo_cuarto.to_frame()
# Out:
#                     id
# room_type
# Entire home/apt  10291
# Hotel room         458
# Private room      9455
# Shared room        367

# %%
### Número de listados por delegación y por tipo de cuarto ###

# %%
tipo_x_del = abnb.groupby(['neighbourhood_cleansed','room_type'])['id'].count()

# %%
tipo_x_del.to_frame().unstack()
# Out:
#                                     id
# room_type              Entire home/apt Hotel room Private room Shared room
# neighbourhood_cleansed
# Azcapotzalco                      82.0        1.0        160.0         4.0
# Benito Juárez                   1392.0       55.0       1831.0        43.0
# Coyoacán                         605.0       26.0       1098.0        41.0
# Cuajimalpa de Morelos            232.0       15.0        178.0         6.0
# Cuauhtémoc                      4782.0      246.0       2975.0       137.0
# Gustavo A. Madero                105.0       17.0        201.0        14.0
# Iztacalco                        115.0        1.0        142.0        11.0
# Iztapalapa                        59.0        1.0        195.0        12.0
# La Magdalena Contreras            50.0        1.0         88.0         3.0
# Miguel Hidalgo                  1946.0       62.0       1230.0        35.0
# Milpa Alta                         8.0        NaN          6.0         2.0
# ...

# %%
### Precio promedio de listados por tipo de cuarto ###

# %%
precio_xcuarto = abnb.groupby('room_type')['price'].mean().to_frame()

# %%
precio_xcuarto
# Out:
#                        price
# room_type
# Entire home/apt  1568.449130
# Hotel room       1554.314410
# Private room      696.255949
# Shared room       653.948229

# %% [markdown]
# ###### Precio promedio por delegación y por tipo de listado

# %%
tipo_x_del_precio = abnb.groupby(['neighbourhood_cleansed','room_type'])['price'].mean().to_frame().unstack()

# %%
tipo_x_del_std = abnb.groupby(['neighbourhood_cleansed','room_type'])['price'].std().to_frame().unstack()

# %%
### Desviación estándar ###

# %%
tipo_x_del_std
# Out:
#                                  price
# room_type              Entire home/apt   Hotel room  Private room  Shared room
# neighbourhood_cleansed
# Azcapotzalco                851.021323          NaN   1581.000097   103.720779
# Benito Juárez              1592.703104  1149.386113   1103.810138  4104.708805
# Coyoacán                   2579.444707  1101.687503   2310.090221  1273.964014
# Cuajimalpa de Morelos      1141.004005   607.054810   1924.019954   384.662839
# Cuauhtémoc                 2690.083612  1552.470991   1075.555714   938.429791
# Gustavo A. Madero           788.902142   142.287768    414.289687   310.622107
# Iztacalco                  1152.237339          NaN   1013.962450   230.461474
# Iztapalapa                 1017.255600          NaN  25111.287856   596.494983
# La Magdalena Contreras     1034.921165          NaN    336.092521   215.640905
# Miguel Hidalgo             4404.235657  1979.209424   1001.013654   788.339093
# ...

# %%
#### Precio ####

# %%
tipo_x_del_precio
# Out:
#                                  price
# room_type              Entire home/apt   Hotel room Private room  Shared room
# neighbourhood_cleansed
# Azcapotzalco                967.939024   291.000000   590.500000   252.000000
# Benito Juárez              1119.385776  1324.454545   557.618788  1598.232558
# Coyoacán                   1284.180165  1650.076923   651.989982   564.121951
# Cuajimalpa de Morelos      1596.008621  1709.600000   931.528090   558.500000
# Cuauhtémoc                 1644.062108  1538.930894   675.578487   563.496350
# Gustavo A. Madero           889.666667   547.058824   415.024876   401.357143
# Iztacalco                   793.626087   600.000000   531.633803   369.909091
# Iztapalapa                  904.101695   504.000000  2418.810256   443.916667
# La Magdalena Contreras     1294.240000  1956.000000   519.284091   355.000000
# Miguel Hidalgo             2093.043679  2203.370968   751.517886   632.057143
# ...

# %% [markdown]
# ###### Precio y Número de listados por colonia

# %%
precio_x_col = merge_2.groupby('zipcode')['price'].mean().to_frame().sort_values(by='price', ascending=False)

# %%
precio_x_col.reset_index(inplace=True)

# %%
precio_num_x_col = tabla_merge_3.merge(precio_x_col, on='zipcode', how = 'inner').sort_values(by='Número de Listados', ascending = False).set_index('zipcode')

# %%
precio_num_x_col_2 = precio_num_x_col[['Número de Listados', 'price','neighbourhood', 'delegación']].head(25)

# %%
precio_num_x_col
# Out:
#                                                   geometry  Número de Listados                             neighbourhood              delegación        price
# zipcode
# 6700     POLYGON ((2798023.530199997 828094.8731000014,...                1632                                Roma Norte              Cuauhtémoc  1239.378676
# 6100     POLYGON ((2795668.2148 826310.7696999982, 2795...                1034                                 Hipódromo              Cuauhtémoc  1367.206963
# 6000     POLYGON ((2799355.643299997 829209.1273000017,...                 748                           Centro (Área 1)              Cuauhtémoc  1036.058824
# 6140     POLYGON ((2796080.471199997 827160.3649000004,...                 686                                   Condesa              Cuauhtémoc  1201.094752
# 6600     POLYGON ((2798036.355099998 828270.1096, 27978...                 668                                    Juárez              Cuauhtémoc  1129.365269
# ...

# %%
precio_num_x_col[['Número de Listados', 'price','neighbourhood', 'delegación']].sort_values(by='price', ascending=False)
# Out:
#          Número de Listados        price                                    neighbourhood              delegación
# zipcode
# 7400                      1  4009.000000                              Salvador Díaz Mirón       Gustavo A. Madero
# 7370                      1  3719.000000                                      Capultitlan       Gustavo A. Madero
# 16030                     1  3506.000000                              Ampliación La Noria              Xochimilco
# 16030                     1  3506.000000                        Potrero de San Bernardino              Xochimilco
# 16030                     1  3506.000000                                        Huichapan              Xochimilco
# 16030                     1  3506.000000                                         La Noria              Xochimilco
# 14476                     1  3506.000000                                         La Palma                 Tlalpan
# ...

# %%
merge_2.loc[abnb]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-685-b62df4184fa3> in <module>
# ----> 1 merge_2.loc[abnb]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1897
#    1898                 if hasattr(key, 'ndim') and key.ndim > 1:
# -> 1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
#    1901                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
merge_2.head()
# Out:
#    zipcode                                           geometry       id                           listing_url       scrape_id last_scraped                                               name                                            summary                                              space                                        description experiences_offered                              neighborhood_overview                                              notes                                            transit                                             access                                        interaction                                        house_rules  thumbnail_url  medium_url                                        picture_url  xl_picture_url  host_id                                   host_url        host_name  host_since                     host_location                                         host_about host_response_time host_response_rate  host_acceptance_rate  \
# ...
